# %% [markdown]
# # Uvod #
#
# U ovoj vježbi izgradit ćete model za predviđanje otkazivanja hotela s binarnim klasifikatorom.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %% [markdown]
# Prvo učitajte skup podataka *Hotel cancellations*.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('./input/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Definirajte model #
#
# Model koji ćemo ovaj put koristiti imat će i batch normalization i dropout layer. Radi lakšeg čitanja razbili smo dijagram u blokove, ali možete ga definirati sloj po sloj kao i obično.
#
# Definirajte model s arhitekturom danom ovim dijagramom:
#
# <figure style="padding: 1em;">
# <img src="figs/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Dijagram binarnog klasifikatora.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(units=256, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(units=256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(units=1, activation='sigmoid')
])
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\normalization\batch_normalization.py:143: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # 2) Dodajte optimizator, loss i metriku #
#
# Sada sastavite model s Adamovim optimizatorom i binarnim verzijama cross-entropy loss-a i metrike accuracy-a.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %% [markdown]
# Na kraju, pokrenite ovu ćeliju da uvježbate model i pogledate krivulje učenja. Može trajati oko 60 do 70 epoha, što može potrajati minutu ili dvije.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - binary_accuracy: 0.7501 - loss: 0.5078 - val_binary_accuracy: 0.8079 - val_loss: 0.4367
# Epoch 2/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - binary_accuracy: 0.7987 - loss: 0.4260 - val_binary_accuracy: 0.8139 - val_loss: 0.4006
# Epoch 3/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - binary_accuracy: 0.8074 - loss: 0.4109 - val_binary_accuracy: 0.8187 - val_loss: 0.3914
# Epoch 4/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - binary_accuracy: 0.8101 - loss: 0.4049 - val_binary_accuracy: 0.8215 - val_loss: 0.3909
# Epoch 5/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - binary_accuracy: 0.8140 - loss: 0.3983 - val_binary_accuracy: 0.8242 - val_loss: 0.3831
# Epoch 6/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.8161 - loss: 0.3940 - val_binary_accuracy: 0.8248 - val_loss: 0.3803
# Epoch 7/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8179 - loss: 0.3898 - val_binary_accuracy: 0.8276 - val_loss: 0.3758
# Epoch 8/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - binary_accuracy: 0.8203 - loss: 0.3864 - val_binary_accuracy: 0.8296 - val_loss: 0.3727
# Epoch 9/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8228 - loss: 0.3820 - val_binary_accuracy: 0.8293 - val_loss: 0.3785
# Epoch 10/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - binary_accuracy: 0.8241 - loss: 0.3785 - val_binary_accuracy: 0.8318 - val_loss: 0.3721
# Epoch 11/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - binary_accuracy: 0.8277 - loss: 0.3732 - val_binary_accuracy: 0.8339 - val_loss: 0.3679
# Epoch 12/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8288 - loss: 0.3723 - val_binary_accuracy: 0.8353 - val_loss: 0.3659
# Epoch 13/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - binary_accuracy: 0.8317 - loss: 0.3673 - val_binary_accuracy: 0.8384 - val_loss: 0.3624
# Epoch 14/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8309 - loss: 0.3667 - val_binary_accuracy: 0.8373 - val_loss: 0.3599
# Epoch 15/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - binary_accuracy: 0.8303 - loss: 0.3666 - val_binary_accuracy: 0.8362 - val_loss: 0.3631
# Epoch 16/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8311 - loss: 0.3632 - val_binary_accuracy: 0.8389 - val_loss: 0.3593
# Epoch 17/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - binary_accuracy: 0.8345 - loss: 0.3598 - val_binary_accuracy: 0.8392 - val_loss: 0.3592
# Epoch 18/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - binary_accuracy: 0.8343 - loss: 0.3612 - val_binary_accuracy: 0.8361 - val_loss: 0.3612
# Epoch 19/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - binary_accuracy: 0.8347 - loss: 0.3562 - val_binary_accuracy: 0.8419 - val_loss: 0.3588
# Epoch 20/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - binary_accuracy: 0.8357 - loss: 0.3559 - val_binary_accuracy: 0.8412 - val_loss: 0.3541
# Epoch 21/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8386 - loss: 0.3501 - val_binary_accuracy: 0.8394 - val_loss: 0.3566
# Epoch 22/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8336 - loss: 0.3537 - val_binary_accuracy: 0.8420 - val_loss: 0.3546
# Epoch 23/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8369 - loss: 0.3515 - val_binary_accuracy: 0.8405 - val_loss: 0.3524
# Epoch 24/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - binary_accuracy: 0.8377 - loss: 0.3508 - val_binary_accuracy: 0.8422 - val_loss: 0.3534
# Epoch 25/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.8373 - loss: 0.3503 - val_binary_accuracy: 0.8425 - val_loss: 0.3549
# Epoch 26/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8389 - loss: 0.3467 - val_binary_accuracy: 0.8423 - val_loss: 0.3557
# Epoch 27/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - binary_accuracy: 0.8388 - loss: 0.3468 - val_binary_accuracy: 0.8416 - val_loss: 0.3520
# Epoch 28/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - binary_accuracy: 0.8413 - loss: 0.3455 - val_binary_accuracy: 0.8431 - val_loss: 0.3544
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and verify #
#
#
# Što mislite o krivuljama učenja? Izgleda li kao model underfit ili overfit? Je li cross-entropy loss bio dobra zamjena za accuracy?
